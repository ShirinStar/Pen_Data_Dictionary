# %%
import mysql.connector as sql
import pandas as pd
import datetime as dt
import numpy as np
from sorted_months_weekdays import *
from sort_dataframeby_monthorweek import *
import matplotlib.pyplot as plt
import math
import json
from pandas.io.json import json_normalize
import requests
import matplotlib.dates as mdates
from datetime import date, timedelta

# %%
db_connection = sql.connect(host='localhost', database='collection_visits', user='pandas', password='password')

pensActivity = pd.read_sql('SELECT * FROM PensActivity', con=db_connection)
pensActivity['created'] = pd.to_datetime(pensActivity['created'], unit='s').dt.tz_localize('utc').dt.tz_convert('US/Eastern')
pensActivity['lastmodified'] = pd.to_datetime(pensActivity['lastmodified'], unit='s').dt.tz_localize('utc').dt.tz_convert('US/Eastern')
pensActivity['created'].replace(0, np.nan, inplace=True)
pensActivity['lastmodified'].replace(0, np.nan, inplace=True)
pensActivity['notes'].replace(r'^\s*$', np.NaN, regex=True, inplace=True)
pensActivity['notes'] = pensActivity['notes'].astype('category')
pensActivity.sort_values(by='created', inplace=True)

pensCheckouts = pd.read_sql('SELECT * FROM PensCheckouts', con=db_connection)
pensCheckouts['start'] = pd.to_datetime(pensCheckouts['start'], unit='s').dt.tz_localize('utc').dt.tz_convert('US/Eastern')
pensCheckouts['start'].replace(0, np.nan, inplace=True)
pensCheckouts['end'].replace(0, np.nan, inplace=True)
pensCheckouts['end'] = pd.to_datetime(pensCheckouts['end'], unit='s').dt.tz_localize('utc').dt.tz_convert('US/Eastern')
pensCheckouts['start_ip'].replace(0, np.nan, inplace=True)
pensCheckouts['end_ip'].replace(0, np.nan, inplace=True)
pensCheckouts['start_ip'] = pensCheckouts['start_ip'].astype('category')
pensCheckouts['end_ip'] = pensCheckouts['end_ip'].astype('category')
pensCheckouts.set_index('id', inplace=True)
pensCheckouts.sort_index(inplace=True)
###DROPED COLUMNS####
pensCheckouts.drop(['start_ip', 'end_ip'], axis=1, inplace=True)

# %% [markdown]
# ## merge on visit_id

# %%
pensCheckouts.set_index(['visit_id'], inplace=True)
pensActivity.set_index(['visit_id'], inplace=True)
checkout_activity = pensCheckouts.join(pensActivity, how='left', lsuffix='_checkout', rsuffix='_activity')
checkout_activity
# Out:
#            pen_id_checkout                     start  \
# visit_id
# 793401                   8 2014-10-23 11:36:51-04:00
# 793449                   3 2014-10-23 12:25:42-04:00
# 793527                   9 2014-10-23 22:04:59-04:00
# 793571                   2 2014-10-24 11:05:23-04:00
# 793681                   7 2014-10-24 20:02:19-04:00
# ...                    ...                       ...
# 132777683          1520099 2020-07-02 16:22:28-04:00
# 132794701          1520099 2020-07-06 13:42:18-04:00
# 132806719          1520099 2020-07-09 09:12:28-04:00
# 132806727          1520099 2020-07-09 09:16:41-04:00
# 132806735          1520099 2020-07-09 09:20:03-04:00
#
#                                 end  pen_id_activity  \
# visit_id
# 793401    2014-10-24 20:44:42-04:00              NaN
# 793449    2014-10-24 20:44:42-04:00              NaN
# 793527    2014-10-24 20:44:42-04:00              NaN
# 793571    2014-10-27 13:53:29-04:00              NaN
# 793681    2014-10-27 13:53:29-04:00              NaN
# ...                             ...              ...
# 132777683 2020-07-02 16:22:44-04:00        1524473.0
# 132794701 2020-07-06 13:43:00-04:00        1524473.0
# 132806719 2020-07-09 09:12:46-04:00        1524473.0
# 132806727 2020-07-09 09:17:00-04:00        1524473.0
# 132806735 2020-07-09 09:20:15-04:00        1524473.0
#
#                                         fingerprint  \
# visit_id
# 793401                                          NaN
# 793449                                          NaN
# 793527                                          NaN
# 793571                                          NaN
# 793681                                          NaN
# ...                                             ...
# 132777683  8de20189e64f86c4f892b98ca7d30077b00b3874
# 132794701  c24003e782909cd4a8385fd84970943237aa605b
# 132806719  513e424fc16895f97ae6e70e9bb74f9a58c59229
# 132806727  ab224c85d1194f9136c2903b41c6f56a34d7875b
# 132806735  c7d1bf485fde66a2c244381971f3ea1151cbf42c
#
#                                                     activity notes  status_id  \
# visit_id
# 793401                                                   NaN   NaN        NaN
# 793449                                                   NaN   NaN        NaN
# 793527                                                   NaN   NaN        NaN
# 793571                                                   NaN   NaN        NaN
# 793681                                                   NaN   NaN        NaN
# ...                                                      ...   ...        ...
# 132777683  {"ticket_id":"tzctj","registers":"None","colle...   NaN        1.0
# 132794701  {"ticket_id":"gz65","registers":"None","collec...   NaN        1.0
# 132806719  {"ticket_id":"56bs6","registers":"None","colle...   NaN        1.0
# 132806727  {"ticket_id":"cvszd","registers":"None","colle...   NaN        1.0
# 132806735  {"ticket_id":"zrbqg","registers":"None","colle...   NaN        1.0
#
#                             created              lastmodified  \
# visit_id
# 793401                          NaT                       NaT
# 793449                          NaT                       NaT
# 793527                          NaT                       NaT
# 793571                          NaT                       NaT
# 793681                          NaT                       NaT
# ...                             ...                       ...
# 132777683 2020-07-02 16:22:39-04:00 2020-07-02 16:22:39-04:00
# 132794701 2020-07-06 13:42:37-04:00 2020-07-06 13:42:37-04:00
# 132806719 2020-07-09 09:12:38-04:00 2020-07-09 09:12:38-04:00
# 132806727 2020-07-09 09:16:52-04:00 2020-07-09 09:16:52-04:00
# 132806735 2020-07-09 09:20:09-04:00 2020-07-09 09:20:09-04:00
#
#            time_to_process  count_items
# visit_id
# 793401                 NaN          NaN
# 793449                 NaN          NaN
# 793527                 NaN          NaN
# 793571                 NaN          NaN
# 793681                 NaN          NaN
# ...                    ...          ...
# 132777683            161.0          1.0
# 132794701            159.0          1.0
# 132806719            172.0          1.0
# 132806727            122.0          1.0
# 132806735            164.0          1.0
#
# [859205 rows x 12 columns]

# %%
checkout_activity_openinghours = checkout_activity.set_index('start')
checkout_activity_openinghours = checkout_activity_openinghours.between_time('10:00', '18:00')
checkout_activity_openinghours.reset_index(inplace=True)
checkout_activity_openinghours
# Out:
#                            start  pen_id_checkout                       end  \
# 0      2014-10-23 11:36:51-04:00                8 2014-10-24 20:44:42-04:00
# 1      2014-10-23 12:25:42-04:00                3 2014-10-24 20:44:42-04:00
# 2      2014-10-24 11:05:23-04:00                2 2014-10-27 13:53:29-04:00
# 3      2014-10-27 13:54:58-04:00                6 2014-10-28 16:49:24-04:00
# 4      2014-10-28 16:02:57-04:00                3 2014-11-03 13:32:08-05:00
# ...                          ...              ...                       ...
# 773973 2020-07-01 14:19:22-04:00          1520099 2020-07-01 14:19:28-04:00
# 773974 2020-07-01 14:19:38-04:00          1520099 2020-07-01 14:32:22-04:00
# 773975 2020-07-02 13:18:56-04:00          1520099 2020-07-02 13:19:22-04:00
# 773976 2020-07-02 16:22:28-04:00          1520099 2020-07-02 16:22:44-04:00
# 773977 2020-07-06 13:42:18-04:00          1520099 2020-07-06 13:43:00-04:00
#
#         pen_id_activity                               fingerprint  \
# 0                   NaN                                       NaN
# 1                   NaN                                       NaN
# 2                   NaN                                       NaN
# 3                   NaN                                       NaN
# 4                   NaN                                       NaN
# ...                 ...                                       ...
# 773973        1524473.0  c381490efa986a976c19b9cc1514b54ae9e720b3
# 773974        1524473.0  c381490efa986a976c19b9cc1514b54ae9e720b3
# 773975        1524473.0  9f31efa2cdfad9c550201a965897f1288d7b5211
# 773976        1524473.0  8de20189e64f86c4f892b98ca7d30077b00b3874
# 773977        1524473.0  c24003e782909cd4a8385fd84970943237aa605b
#
#                                                  activity notes  status_id  \
# 0                                                     NaN   NaN        NaN
# 1                                                     NaN   NaN        NaN
# 2                                                     NaN   NaN        NaN
# 3                                                     NaN   NaN        NaN
# 4                                                     NaN   NaN        NaN
# ...                                                   ...   ...        ...
# 773973  {"ticket_id":"Jtmx","registers":"None","collec...   NaN        1.0
# 773974  {"ticket_id":"Jtmx","registers":"None","collec...   NaN        1.0
# 773975  {"ticket_id":"ppkxy","registers":"None","colle...   NaN        1.0
# 773976  {"ticket_id":"tzctj","registers":"None","colle...   NaN        1.0
# 773977  {"ticket_id":"gz65","registers":"None","collec...   NaN        1.0
#
#                          created              lastmodified  time_to_process  \
# 0                            NaT                       NaT              NaN
# 1                            NaT                       NaT              NaN
# 2                            NaT                       NaT              NaN
# 3                            NaT                       NaT              NaN
# 4                            NaT                       NaT              NaN
# ...                          ...                       ...              ...
# 773973 2020-07-01 14:22:44-04:00 2020-07-01 14:22:44-04:00            117.0
# 773974 2020-07-01 14:22:44-04:00 2020-07-01 14:22:44-04:00            117.0
# 773975 2020-07-02 13:19:11-04:00 2020-07-02 13:19:11-04:00            140.0
# 773976 2020-07-02 16:22:39-04:00 2020-07-02 16:22:39-04:00            161.0
# 773977 2020-07-06 13:42:37-04:00 2020-07-06 13:42:37-04:00            159.0
#
#         count_items
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 773973          1.0
# 773974          1.0
# 773975          1.0
# 773976          1.0
# 773977          1.0
#
# [773978 rows x 12 columns]

# %% [markdown]
# ## did nothing

# %%
did_nothing = checkout_activity_openinghours[checkout_activity_openinghours['pen_id_activity'].isna()]
did_nothing['pen_id_checkout'].count()
# Out:
# 135137

# %%
did_nothing_yealry = did_nothing['start'].groupby(did_nothing.start.dt.to_period('Y')).agg('count')
did_nothing_yealry
# Out:
# /Users/shirin/opt/anaconda3/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py:1102: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   UserWarning,
# start
# 2014      130
# 2015    27959
# 2016    24889
# 2017    21525
# 2018    32013
# 2019    23180
# 2020     5441
# Freq: A-DEC, Name: start, dtype: int64
