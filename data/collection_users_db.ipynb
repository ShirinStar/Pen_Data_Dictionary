# %%
import mysql.connector as sql
import pandas as pd

# %%
db_connection = sql.connect(host='localhost', database='collection_users', user='pandas', password='password')
ShoeboxItems = pd.read_sql('SELECT * FROM UsersShoeboxItems', con=db_connection)
ShoeboxBundles = pd.read_sql('SELECT * FROM UsersShoeboxBundles', con=db_connection)
ShoeboxItemsRenditions = pd.read_sql('SELECT * FROM UsersShoeboxItemsRenditions', con=db_connection)

# %%
pd.set_option('display.max_rows', 15500)

# %%
ShoeboxItems.head(50)
# Out:
#         id  user_id  action_id  tool_id  bundle_id  refers_to_id  \
# 0   789443      199          2        0     789383             0
# 1   789513      199          2        0     789383             0
# 2   789969      231          1        0     789967             1
# 3   789989      231          1        0     789967             1
# 4   789991      231          1        0     789967             1
# 5   789993      231          1        0     789967             1
# 6   789995      231          1        0     789967             1
# 7   790373      247          2        8     790365             1
# 8   790375      247          1        0     790365             1
# 9   790377      247          1        0     790365             1
# 10  790383      247          1        0     790365             1
# 11  790391      247          1        0     790365             1
# 12  790405      247          1        0     790365             1
# ...

# %%
ShoeboxBundles
# Out:
#               id  user_id  type_id  \
# 0         789383      199        1
# 1         789967      231        1
# 2         790365      247        1
# 3         790917      247        1
# 4         796435      247        1
# ...          ...      ...      ...
# 23121  132498395    28814        1
# 23122  132498415    28814        1
# 23123  132777659    28814        1
# 23124  132777661    28814        1
# 23125  132794701    28814        1
#
#                                                 title description  is_public  \
# 0      Your visit to the museum on September 30, 2014                      0
# 1         Your visit to the museum on October 2, 2014                      0
# 2         Your visit to the museum on October 6, 2014                      0
# 3         Your visit to the museum on October 7, 2014                      0
# 4        Your visit to the museum on November 3, 2014                      0
# ...

# %%
ShoeboxItemsRenditions
# Out:
#               id  source_id size  user_id  \
# 0         793425     793423    o        3
# 1         793431     793429    o        3
# 2         793443     793441    o        3
# 3         794987     794985    o      305
# 4         798839     798837    o      247
# ...          ...        ...  ...      ...
# 20818  132873407  132873405    o    28814
# 20819  132873411  132873409    o    28814
# 20820  132873415  132873413    o    28814
# 20821  132873419  132873417    o    28814
# 20822  132873429  132873427    o    28814
#
#                                     fingerprint        secret extension  \
# 0      cf950b593499f7beddb94b860fe58ba1c5c66420  993a58ab9ef5       jpg
# 1      485f83e02e6298268b1dcd9b3bf42bb902e40a0b  00114d3874d8       jpg
# 2      9300eae08eac53aaf50f49e3e794f2e6e0947833  ef7a4bee918a       png
# 3      21b1ef07e0b248d118a93560bb7051822c7103ad  4f09eac38cd3       png
# 4      2e06e0ec0c42b61f2704d69e3f005eee419ce690  668be91e7fc3       obj
# ...

# %%
ShoeboxItems.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1555921 entries, 0 to 1555920
# Data columns (total 22 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   id             1555921 non-null  int64
#  1   user_id        1555921 non-null  int64
#  2   action_id      1555921 non-null  int64
#  3   tool_id        1555921 non-null  int64
#  4   bundle_id      1555921 non-null  int64
#  5   refers_to_id   1555921 non-null  int64
#  6   refers_to_uid  1555921 non-null  int64
#  7   fingerprint    1555921 non-null  object
#  8   title          1555921 non-null  object
#  9   description    1555921 non-null  object
#  10  secret         1555921 non-null  object
#  11  extension      1555921 non-null  object
#  12  mimetype       1555921 non-null  object
#  13  is_public      1555921 non-null  int64
#  14  created        1555921 non-null  int64
#  15  lastmodified   1555921 non-null  int64
#  16  deleted        1555921 non-null  int64
# ...

# %%
ShoeboxItems.nunique()
# Out:
# id               1555921
# user_id            23681
# action_id              2
# tool_id               15
# bundle_id          22589
# refers_to_id           6
# refers_to_uid      75428
# fingerprint        20911
# title               1973
# description          394
# secret             22753
# extension              7
# mimetype              10
# is_public              2
# created           955050
# lastmodified      211013
# deleted            15852
# secret_o           22753
# extras             21552
# status_id              3
# processed           1050
# input_id               4
# dtype: int64
